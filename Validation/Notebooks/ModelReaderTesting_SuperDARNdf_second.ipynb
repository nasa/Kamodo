# %% [markdown]
# # Demo notebook for Model Reader

# %%
# Delete the time files before running.
model = 'SuperDARN_df'
variables_requested = ['V', 'theta_Btilt']
# change file path to where data is stored on your machine
file_dir = 'C:/Users/rringuet/Kamodo_Data/SuperDARN/fullday-defaultgrid/'
from os.path import isfile
from os import remove
if isfile(file_dir+model+'_times.txt'):
    remove(file_dir+model+'_times.txt')
if isfile(file_dir+model+'_list.txt'):
    remove(file_dir+model+'_list.txt')

# %%
# Check that time files creation works, that reader works for one variable,
# and that an unknown variable request does not break it.
import kamodo_ccmc.flythrough.model_wrapper as MW
reader = MW.Model_Reader(model)
kamodo_object = reader(file_dir, variables_requested=['Trash'])
kamodo_object
# Out:
# Uniform grid detected. All files already converted.
# Creating the time files...done.
# Variable name(s) not recognized: ['Trash']
# {}

# %%
# Check that reading the time files works and that reader works for one variable,
kamodo_object = reader(file_dir, variables_requested=['V'])
kamodo_object
# Out:
# {V(rvec_SMsph3D): <function time_interp.<locals>.interp at 0x0000028A05EE8438>, V: <function time_interp.<locals>.interp at 0x0000028A05EE8438>, V_ijk(time, lon, lat): <function gridify.<locals>.decorator_gridify.<locals>.wrapped at 0x0000028A04324AF8>, V_ijk: <function gridify.<locals>.decorator_gridify.<locals>.wrapped at 0x0000028A04324AF8>}

# %%
# Confirm that interpolation works
print(kamodo_object.V([10.2, 10., 70.]))  # breaks during data from other run b/c lat grids are diff (hr=5.2)
print(kamodo_object.V_ijk(time=10.2, lon=10., lat=70.))
print(kamodo_object.V_ijk(time=10.2, lon=10).shape)
# Out:
# Time slice index 61 added from file.
# Time slice index 62 added from file.
# [0.11874367]
# 0.11874367485579619
# (32,)

# %%
# Check that reading the time files works, and that the reader works for all variables
kamodo_object = reader(file_dir)
kamodo_object
# Out:
# {theta_Btilt(time_SMsph): <function create_interp.<locals>.interp at 0x0000028A0608C9D8>, theta_Btilt: <function create_interp.<locals>.interp at 0x0000028A0608C9D8>, theta_Btilt_ijk(time): <function gridify.<locals>.decorator_gridify.<locals>.wrapped at 0x0000028A0608CD38>, theta_Btilt_ijk: <function gridify.<locals>.decorator_gridify.<locals>.wrapped at 0x0000028A0608CD38>, E_sw(time_SMsph): <function create_interp.<locals>.interp at 0x0000028A06087558>, E_sw: <function create_interp.<locals>.interp at 0x0000028A06087558>, E_sw_ijk(time): <function gridify.<locals>.decorator_gridify.<locals>.wrapped at 0x0000028A060878B8>, E_sw_ijk: <function gridify.<locals>.decorator_gridify.<locals>.wrapped at 0x0000028A060878B8>, theta_B(time_SMsph): <function create_interp.<locals>.interp at 0x0000028A05F39048>, theta_B: <function create_interp.<locals>.interp at 0x0000028A05F39048>, theta_B_ijk(time): <function gridify.<locals>.decorator_gridify.<locals>.wrapped at 0x0000028A05F393A8>, theta_B_ijk: <function gridify.<locals>.decorator_gridify.<locals>.wrapped at 0x0000028A05F393A8>, V(rvec_SMsph3D): <function time_interp.<locals>.interp at 0x0000028A05F39D38>, V: <function time_interp.<locals>.interp at 0x0000028A05F39D38>, V_ijk(time, lon, lat): <function gridify.<locals>.decorator_gridify.<locals>.wrapped at 0x0000028A05F39EE8>, V_ijk: <function gridify.<locals>.decorator_gridify.<locals>.wrapped at 0x0000028A05F39EE8>, theta_v(rvec_SMsph3D): <function time_interp.<locals>.interp at 0x0000028A05F2F8B8>, theta_v: <function time_interp.<locals>.interp at 0x0000028A05F2F8B8>, theta_v_ijk(time, lon, lat): <function gridify.<locals>.decorator_gridify.<locals>.wrapped at 0x0000028A05F2FA68>, theta_v_ijk: <function gridify.<locals>.decorator_gridify.<locals>.wrapped at 0x0000028A05F2FA68>, v(rvec_SMsph3D): <function time_interp.<locals>.interp at 0x0000028A060BE558>, v: <function time_interp.<locals>.interp at 0x0000028A060BE558>, v_ijk(time, lon, lat): <function gridify.<locals>.decorator_gridify.<locals>.wrapped at 0x0000028A060BE708>, v_ijk: <function gridify.<locals>.decorator_gridify.<locals>.wrapped at 0x0000028A060BE708>}

# %%
# Check that the kamodo object was built properly.
print(kamodo_object.V([10.2, 10., 70.]))
# Out:
# Time slice index 61 added from file.
# Time slice index 62 added from file.
# [0.11874367]

# %%
# Check that the reader works for the testing subset
kamodo_object = reader(file_dir, variables_requested=variables_requested)
kamodo_object
# Out:
# {V(rvec_SMsph3D): <function time_interp.<locals>.interp at 0x0000028A060C1678>, V: <function time_interp.<locals>.interp at 0x0000028A060C1678>, V_ijk(time, lon, lat): <function gridify.<locals>.decorator_gridify.<locals>.wrapped at 0x0000028A060C18B8>, V_ijk: <function gridify.<locals>.decorator_gridify.<locals>.wrapped at 0x0000028A060C18B8>, theta_Btilt(time_SMsph): <function create_interp.<locals>.interp at 0x0000028A060C1F78>, theta_Btilt: <function create_interp.<locals>.interp at 0x0000028A060C1F78>, theta_Btilt_ijk(time): <function gridify.<locals>.decorator_gridify.<locals>.wrapped at 0x0000028A060C30D8>, theta_Btilt_ijk: <function gridify.<locals>.decorator_gridify.<locals>.wrapped at 0x0000028A060C30D8>}

# %%
# Confirm that the interpolator works for each testing variable and type
print(kamodo_object.V([10.2, 10., 70.]))
print(kamodo_object.V_ijk(time=10.2, lon=10., lat=70.))
print(kamodo_object.V([10.2, 10., 70.]) == kamodo_object.V_ijk(time=10.2, lon=10., lat=70.))
print(kamodo_object.V_ijk(time=10.2, lon=10.).shape)
print(kamodo_object.theta_Btilt([10.2]))
print(kamodo_object.theta_Btilt_ijk(time=10.2))
print(kamodo_object.theta_Btilt([10.2]) == kamodo_object.theta_Btilt_ijk(time=10.2))
print(kamodo_object.theta_Btilt_ijk().shape)
# Out:
# Time slice index 61 added from file.
# Time slice index 62 added from file.
# [0.11874367]
# 0.11874367485579619
# [ True]
# (32,)
# [14.87999965]
# 14.879999653496178
# [ True]
# (144,)

# %%
from kamodo import get_defaults
for var in variables_requested:
    print('\n', var)
    defaults = get_defaults(kamodo_object[var])
    for key in defaults:
        print(key, len(defaults[key]))
        for item in defaults[key]:
            print(item)
    defaults_ijk = get_defaults(kamodo_object[var+'_ijk'])
    for key in defaults_ijk:
        print(key, len(defaults_ijk[key]), defaults_ijk[key].min(), defaults_ijk[key].max())
kamodo_object.filedate
# Out:
#  V
# rvec_SMsph3D 8
# [   0.  -180.    60.5]
# [   0. -180.   90.]
# [  23.83333397 -180.           60.5       ]
# [  23.83333397 -180.           90.        ]
# [  0.  180.   60.5]
# [  0. 180.  90.]
# [ 23.83333397 180.          60.5       ]
# [ 23.83333397 180.          90.        ]
# time 144 0.0 23.833334
# lon 181 -180.0 180.0
# lat 32 60.5 90.0
#
#  theta_Btilt
# time_SMsph 2
# [0.]
# [23.83333397]
# time 144 0.0 23.833334
# datetime.datetime(2020, 5, 5, 0, 0, tzinfo=datetime.timezone.utc)

# %%
fig = kamodo_object.plot('V_ijk', plot_partial={'V_ijk': {'time': 12.}})
fig.update_traces(colorscale="Viridis", ncontours=200, contours=dict(coloring="fill", showlines=False))
fig
# Out:
# <div>                            <div id="5577695a-1fef-480b-825c-e2e0236aad6d" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5577695a-1fef-480b-825c-e2e0236aad6d")) {                    Plotly.newPlot(                        "5577695a-1fef-480b-825c-e2e0236aad6d",                        [{"colorbar":{"title":{"side":"bottom","text":"V_ijk[kV]"}},"meta":"2d-grid","x":[-180.0,-178.0,-176.0,-174.0,-172.0,-170.0,-168.0,-166.0,-163.9999542236328,-162.0,-160.0000457763672,-157.9999542236328,-156.0,-154.0000457763672,-151.9999542236328,-150.0,-148.0000457763672,-145.9999542236328,-144.0,-142.0000457763672,-139.9999542236328,-138.0,-136.0000457763672,-133.9999542236328,-132.0,-130.0000457763672,-127.99994659423828,-126.0,-124.00005340576172,-121.99994659423828,-120.0,-118.00005340576172,-115.99994659423828,-114.0,-112.00005340576172,-109.99994659423828,-108.0,-106.00005340576172,-103.99994659423828,-102.0,-100.00005340576172,-97.99994659423828,-96.0,-94.00005340576172,-91.99994659423828,-90.0,-88.00005340576172,-85.99994659423828,-84.0,-82.00005340576172,-79.99994659423828,-78.0,-76.00005340576172,-73.99994659423828,-72.0,-70.00005340576172,-67.99994659423828,-66.0,-64.00005340576172,-61.99995040893555,-60.0,-58.00004959106445,-55.99995040893555,-54.0,-52.00004959106445,-49.99995040893555,-48.0,-46.00004959106445,-43.99995040893555,-42.0,-40.00004959106445,-37.99995040893555,-36.0,-34.00004959106445,-31.999950408935547,-30.0,-28.000499725341797,-25.999500274658203,-24.0,-22.000499725341797,-19.999500274658203,-18.0,-16.000499725341797,-13.999500274658203,-12.0,-10.000499725341797,-7.999499797821045,-6.0,-4.000500202178955,-1.999500036239624,0.0,1.999500036239624,4.000500202178955,6.0,7.999499797821045,10.000499725341797,12.0,13.999500274658203,16.000499725341797,18.0,19.999500274658203,22.000499725341797,24.0,25.999500274658203,28.000499725341797,30.0,31.999500274658203,34.0004997253418,36.0,37.9995002746582,40.0004997253418,42.0,43.9995002746582,46.0004997253418,48.0,49.9995002746582,52.0004997253418,54.0,55.9995002746582,58.0004997253418,60.0,61.9995002746582,64.00050354003906,66.0,67.99949645996094,70.00050354003906,72.0,73.99949645996094,76.00050354003906,78.0,79.99949645996094,82.00050354003906,84.0,85.99949645996094,88.00050354003906,90.0,91.99949645996094,94.00050354003906,96.0,97.99949645996094,100.00050354003906,102.0,103.99949645996094,106.00050354003906,108.0,109.99949645996094,112.00050354003906,114.0,115.99949645996094,118.00050354003906,120.0,121.99949645996094,124.00050354003906,126.0,127.99949645996094,130.00050354003906,132.0,133.99949645996094,136.00050354003906,138.0,139.99949645996094,142.00050354003906,144.0,145.99949645996094,148.00050354003906,150.0,151.99949645996094,154.00050354003906,156.0,157.99949645996094,160.00050354003906,162.0,163.99949645996094,166.00050354003906,168.0,169.99949645996094,172.00050354003906,174.0,175.99949645996094,178.00050354003906,180.0],"y":[60.5,61.400001525878906,61.5,62.5,63.5,64.5,65.5,66.5,67.5,68.5,69.5,70.5,71.5,72.5,73.5,74.5,75.5,76.5,77.5,78.5,79.5,80.5,81.5,82.5,83.5,84.5,85.5,86.5,87.5,88.5,89.5,90.0],"z":[[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,nu ...

# %%
fig = kamodo_object.plot('V_ijk', plot_partial={'V_ijk': {'lat': 70.2}})
fig.update_traces(colorscale="Viridis", ncontours=200, contours=dict(coloring="fill", showlines=False))
fig
# Out:
# <div>                            <div id="329b3cb2-fb2f-45ba-9b2f-2a3a437f45c6" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("329b3cb2-fb2f-45ba-9b2f-2a3a437f45c6")) {                    Plotly.newPlot(                        "329b3cb2-fb2f-45ba-9b2f-2a3a437f45c6",                        [{"colorbar":{"title":{"side":"bottom","text":"V_ijk[kV]"}},"meta":"2d-grid","x":[0.0,0.1666666716337204,0.3333333432674408,0.5,0.6666666865348816,0.8333333134651184,1.0,1.1666666269302368,1.3333333730697632,1.5,1.6666666269302368,1.8333333730697632,2.0,2.1666667461395264,2.3333332538604736,2.5,2.6666667461395264,2.8333332538604736,3.0,3.1666667461395264,3.3333332538604736,3.5,3.6666667461395264,3.8333332538604736,4.0,4.166666507720947,4.333333492279053,4.5,4.666666507720947,4.833333492279053,5.0,5.166666507720947,5.333333492279053,5.5,5.666666507720947,5.833333492279053,6.0,6.166666507720947,6.333333492279053,6.5,6.666666507720947,6.833333492279053,7.0,7.166666507720947,7.333333492279053,7.5,7.666666507720947,7.833333492279053,8.0,8.166666984558105,8.333333015441895,8.5,8.666666984558105,8.833333015441895,9.0,9.166666984558105,9.333333015441895,9.5,9.666666984558105,9.833333015441895,10.0,10.166666984558105,10.333333015441895,10.5,10.666666984558105,10.833333015441895,11.0,11.166666984558105,11.333333015441895,11.5,11.666666984558105,11.833333015441895,12.0,12.166666984558105,12.333333015441895,12.5,12.666666984558105,12.833333015441895,13.0,13.166666984558105,13.333333015441895,13.5,13.666666984558105,13.833333015441895,14.0,14.166666984558105,14.333333015441895,14.5,14.666666984558105,14.833333015441895,15.0,15.166666984558105,15.333333015441895,15.5,15.666666984558105,15.833333015441895,16.0,16.16666603088379,16.33333396911621,16.5,16.66666603088379,16.83333396911621,17.0,17.16666603088379,17.33333396911621,17.5,17.66666603088379,17.83333396911621,18.0,18.16666603088379,18.33333396911621,18.5,18.66666603088379,18.83333396911621,19.0,19.16666603088379,19.33333396911621,19.5,19.66666603088379,19.83333396911621,20.0,20.16666603088379,20.33333396911621,20.5,20.66666603088379,20.83333396911621,21.0,21.16666603088379,21.33333396911621,21.5,21.66666603088379,21.83333396911621,22.0,22.16666603088379,22.33333396911621,22.5,22.66666603088379,22.83333396911621,23.0,23.16666603088379,23.33333396911621,23.5,23.66666603088379,23.83333396911621],"y":[-180.0,-178.0,-176.0,-174.0,-172.0,-170.0,-168.0,-166.0,-163.9999542236328,-162.0,-160.0000457763672,-157.9999542236328,-156.0,-154.0000457763672,-151.9999542236328,-150.0,-148.0000457763672,-145.9999542236328,-144.0,-142.0000457763672,-139.9999542236328,-138.0,-136.0000457763672,-133.9999542236328,-132.0,-130.0000457763672,-127.99994659423828,-126.0,-124.00005340576172,-121.99994659423828,-120.0,-118.00005340576172,-115.99994659423828,-114.0,-112.00005340576172,-109.99994659423828,-108.0,-106.00005340576172,-103.99994659423828,-102.0,-100.00005340576172,-97.99994659423828,-96.0,-94.00005340576172,-91.99994659423828,-90.0,-88.00005340576172,-85.99994659423828,-84.0,-82.00005340576172,-79.99994659423828,-78.0,-76.00005340576172,-73.99994659423828,-72.0,-70.00005340576172,-67.99994659423828,-66.0,-64.00005340576172,-61.99995040893555,-60.0,-58.00004959106445,-55.99995040893555,-54.0,-52.00004959106445,-49.99995040893555,-48.0,-46.00004959106445,-43.99995040893555,-42.0,-40.00004959106445,-37.99995040893555,-36.0,-34.00004959106445,-31.999950408935547,-30.0,-28.000499725341797,-25.999500274658203,-24.0,-22.000499725341797,-19.999500274658203,-18.0,-16.000499725341797,-13.999500274658203,-12.0,-10.000499725341797,-7.999499797821045,-6.0,-4.000500202178955,-1.999500036239624,0.0,1.999500036239624,4.000500202178955,6.0,7.999499797821045,10.000499725341797,12.0,13.9995002746582 ...

# %%
fig = kamodo_object.plot('V_ijk', plot_partial={'V_ijk': {'lon': -70.2}})
fig.update_traces(colorscale="Viridis", ncontours=200, contours=dict(coloring="fill", showlines=False))
fig
# Out:
# <div>                            <div id="58eaa38c-072c-4ffa-9ce9-2da465634bb8" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58eaa38c-072c-4ffa-9ce9-2da465634bb8")) {                    Plotly.newPlot(                        "58eaa38c-072c-4ffa-9ce9-2da465634bb8",                        [{"colorbar":{"title":{"side":"bottom","text":"V_ijk[kV]"}},"meta":"2d-grid","x":[0.0,0.1666666716337204,0.3333333432674408,0.5,0.6666666865348816,0.8333333134651184,1.0,1.1666666269302368,1.3333333730697632,1.5,1.6666666269302368,1.8333333730697632,2.0,2.1666667461395264,2.3333332538604736,2.5,2.6666667461395264,2.8333332538604736,3.0,3.1666667461395264,3.3333332538604736,3.5,3.6666667461395264,3.8333332538604736,4.0,4.166666507720947,4.333333492279053,4.5,4.666666507720947,4.833333492279053,5.0,5.166666507720947,5.333333492279053,5.5,5.666666507720947,5.833333492279053,6.0,6.166666507720947,6.333333492279053,6.5,6.666666507720947,6.833333492279053,7.0,7.166666507720947,7.333333492279053,7.5,7.666666507720947,7.833333492279053,8.0,8.166666984558105,8.333333015441895,8.5,8.666666984558105,8.833333015441895,9.0,9.166666984558105,9.333333015441895,9.5,9.666666984558105,9.833333015441895,10.0,10.166666984558105,10.333333015441895,10.5,10.666666984558105,10.833333015441895,11.0,11.166666984558105,11.333333015441895,11.5,11.666666984558105,11.833333015441895,12.0,12.166666984558105,12.333333015441895,12.5,12.666666984558105,12.833333015441895,13.0,13.166666984558105,13.333333015441895,13.5,13.666666984558105,13.833333015441895,14.0,14.166666984558105,14.333333015441895,14.5,14.666666984558105,14.833333015441895,15.0,15.166666984558105,15.333333015441895,15.5,15.666666984558105,15.833333015441895,16.0,16.16666603088379,16.33333396911621,16.5,16.66666603088379,16.83333396911621,17.0,17.16666603088379,17.33333396911621,17.5,17.66666603088379,17.83333396911621,18.0,18.16666603088379,18.33333396911621,18.5,18.66666603088379,18.83333396911621,19.0,19.16666603088379,19.33333396911621,19.5,19.66666603088379,19.83333396911621,20.0,20.16666603088379,20.33333396911621,20.5,20.66666603088379,20.83333396911621,21.0,21.16666603088379,21.33333396911621,21.5,21.66666603088379,21.83333396911621,22.0,22.16666603088379,22.33333396911621,22.5,22.66666603088379,22.83333396911621,23.0,23.16666603088379,23.33333396911621,23.5,23.66666603088379,23.83333396911621],"y":[60.5,61.400001525878906,61.5,62.5,63.5,64.5,65.5,66.5,67.5,68.5,69.5,70.5,71.5,72.5,73.5,74.5,75.5,76.5,77.5,78.5,79.5,80.5,81.5,82.5,83.5,84.5,85.5,86.5,87.5,88.5,89.5,90.0],"z":[[null,0.15642580447647964,0.15745201480934487,0.15845651556848409,0.15943800893473997,0.16039571105904527,0.1613265120930531,0.16222871621227866,0.16310192118206301,0.1639434193887182,0.16475211264065856,0.16552701597148722,0.16626611623468507,0.16696851784575387,0.1676331211233498,0.16825802912565874,0.16884312862749168,0.1693856241230202,0.16988632628411793,0.17034332624732548,0.17075662252288487,0.17112513182037153,0.17144802707699258,0.1717242235125655,0.17195373602825145,0.17213653631148607,0.17227162449471137,0.17235903038024972,0.1723988254693225,0.1723908384469226,0.17233422734909595,0.1722308310278386,0.17207892683585943,0.1718801361169058,0.17163383590503034,0.17134072364691783,0.17100202417074606,0.17061752592729842,0.1701883256184026,0.16971542311161658,0.1691988303285856,0.1686405321032644,0.16804042713210926,0.16739972981141085,0.1667201210644927,0.16600282720929066,0.16524882129055635,0.16445901379394923,0.1636354163762304,0.16277901251403876,0.16189191367792113,0.16097581718212028,0.160031110360134,0.15906051274729543,0.15806501228951733,0.1570467055561854,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null ...

# %%
kamodo_object.plot('V_ijk', plot_partial={'V_ijk': {'lon': -70.2, 'lat': 70.2}})
# Out:
# <div>                            <div id="cc7c2dab-2102-4cde-9e13-92d075d35132" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc7c2dab-2102-4cde-9e13-92d075d35132")) {                    Plotly.newPlot(                        "cc7c2dab-2102-4cde-9e13-92d075d35132",                        [{"meta":"line","name":"V_ijk[kV]","x":[0.0,0.1666666716337204,0.3333333432674408,0.5,0.6666666865348816,0.8333333134651184,1.0,1.1666666269302368,1.3333333730697632,1.5,1.6666666269302368,1.8333333730697632,2.0,2.1666667461395264,2.3333332538604736,2.5,2.6666667461395264,2.8333332538604736,3.0,3.1666667461395264,3.3333332538604736,3.5,3.6666667461395264,3.8333332538604736,4.0,4.166666507720947,4.333333492279053,4.5,4.666666507720947,4.833333492279053,5.0,5.166666507720947,5.333333492279053,5.5,5.666666507720947,5.833333492279053,6.0,6.166666507720947,6.333333492279053,6.5,6.666666507720947,6.833333492279053,7.0,7.166666507720947,7.333333492279053,7.5,7.666666507720947,7.833333492279053,8.0,8.166666984558105,8.333333015441895,8.5,8.666666984558105,8.833333015441895,9.0,9.166666984558105,9.333333015441895,9.5,9.666666984558105,9.833333015441895,10.0,10.166666984558105,10.333333015441895,10.5,10.666666984558105,10.833333015441895,11.0,11.166666984558105,11.333333015441895,11.5,11.666666984558105,11.833333015441895,12.0,12.166666984558105,12.333333015441895,12.5,12.666666984558105,12.833333015441895,13.0,13.166666984558105,13.333333015441895,13.5,13.666666984558105,13.833333015441895,14.0,14.166666984558105,14.333333015441895,14.5,14.666666984558105,14.833333015441895,15.0,15.166666984558105,15.333333015441895,15.5,15.666666984558105,15.833333015441895,16.0,16.16666603088379,16.33333396911621,16.5,16.66666603088379,16.83333396911621,17.0,17.16666603088379,17.33333396911621,17.5,17.66666603088379,17.83333396911621,18.0,18.16666603088379,18.33333396911621,18.5,18.66666603088379,18.83333396911621,19.0,19.16666603088379,19.33333396911621,19.5,19.66666603088379,19.83333396911621,20.0,20.16666603088379,20.33333396911621,20.5,20.66666603088379,20.83333396911621,21.0,21.16666603088379,21.33333396911621,21.5,21.66666603088379,21.83333396911621,22.0,22.16666603088379,22.33333396911621,22.5,22.66666603088379,22.83333396911621,23.0,23.16666603088379,23.33333396911621,23.5,23.66666603088379,23.83333396911621],"y":[3.239392847033592,4.257025987976041,4.226930945847874,4.197459776434677,4.168659462120033,4.140580988960606,4.1132835606442555,4.08680726454197,4.061198699820021,4.036508594319882,4.012781448843561,3.9900556128848494,3.9683690283684054,3.9477615990009736,3.928276900708414,3.9099469815717356,3.8927979432398354,3.876866108958004,3.862185913571472,3.848772315253321,3.836654145611075,3.8258485446715573,3.8163854363958984,3.808276972768785,3.801539013530472,3.7961825090841397,3.7922180001094157,3.7896470524966572,3.7884815588980736,3.788725548599112,3.7903730560987596,3.7934229467973273,3.797874605722715,3.8037151651818286,3.8109317266493217,3.819515128010335,3.8294595422540585,3.840727036973097,3.8533198678673486,3.867197355770905,3.88235015287058,3.8987398684291845,3.916337174824265,3.9351229991424908,3.955060672274058,3.976108030159696,3.998227390636973,4.0213865389037755,4.045546565317302,4.0706615076802475,4.096681624485514,4.123576513181497,4.151281755274107,4.179752320656051,4.208950232416296,4.238808587534025,4.269286743434097,3.2443382214159655,3.256697217062224,3.2692328247231495,3.281919777077351,3.2947388075773256,3.3076650469592868,3.3206755000463755,3.333749154965094,3.3468584080696058,3.359982981799593,3.3730970912458913,3.386173600111211,3.3991955185993623,3.4121285196147384,3.4249526544095295,3.437649153115836,3.450182057037877,3.4604256628816463,3.4604256628816463,3.4604256628816463,3.46042566288164 ...

# %%
kamodo_object.plot('theta_Btilt_ijk')
# Out:
# <div>                            <div id="5a56ce1a-5913-4617-b71c-2bf661670095" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a56ce1a-5913-4617-b71c-2bf661670095")) {                    Plotly.newPlot(                        "5a56ce1a-5913-4617-b71c-2bf661670095",                        [{"meta":"line","name":"theta_Btilt_ijk[deg]","x":[0.0,0.1666666716337204,0.3333333432674408,0.5,0.6666666865348816,0.8333333134651184,1.0,1.1666666269302368,1.3333333730697632,1.5,1.6666666269302368,1.8333333730697632,2.0,2.1666667461395264,2.3333332538604736,2.5,2.6666667461395264,2.8333332538604736,3.0,3.1666667461395264,3.3333332538604736,3.5,3.6666667461395264,3.8333332538604736,4.0,4.166666507720947,4.333333492279053,4.5,4.666666507720947,4.833333492279053,5.0,5.166666507720947,5.333333492279053,5.5,5.666666507720947,5.833333492279053,6.0,6.166666507720947,6.333333492279053,6.5,6.666666507720947,6.833333492279053,7.0,7.166666507720947,7.333333492279053,7.5,7.666666507720947,7.833333492279053,8.0,8.166666984558105,8.333333015441895,8.5,8.666666984558105,8.833333015441895,9.0,9.166666984558105,9.333333015441895,9.5,9.666666984558105,9.833333015441895,10.0,10.166666984558105,10.333333015441895,10.5,10.666666984558105,10.833333015441895,11.0,11.166666984558105,11.333333015441895,11.5,11.666666984558105,11.833333015441895,12.0,12.166666984558105,12.333333015441895,12.5,12.666666984558105,12.833333015441895,13.0,13.166666984558105,13.333333015441895,13.5,13.666666984558105,13.833333015441895,14.0,14.166666984558105,14.333333015441895,14.5,14.666666984558105,14.833333015441895,15.0,15.166666984558105,15.333333015441895,15.5,15.666666984558105,15.833333015441895,16.0,16.16666603088379,16.33333396911621,16.5,16.66666603088379,16.83333396911621,17.0,17.16666603088379,17.33333396911621,17.5,17.66666603088379,17.83333396911621,18.0,18.16666603088379,18.33333396911621,18.5,18.66666603088379,18.83333396911621,19.0,19.16666603088379,19.33333396911621,19.5,19.66666603088379,19.83333396911621,20.0,20.16666603088379,20.33333396911621,20.5,20.66666603088379,20.83333396911621,21.0,21.16666603088379,21.33333396911621,21.5,21.66666603088379,21.83333396911621,22.0,22.16666603088379,22.33333396911621,22.5,22.66666603088379,22.83333396911621,23.0,23.16666603088379,23.33333396911621,23.5,23.66666603088379,23.83333396911621],"y":[13.100000381469727,12.699999809265137,12.399999618530273,12.0,11.600000381469727,11.300000190734863,11.0,10.600000381469727,10.300000190734863,10.0,9.699999809265137,9.5,9.199999809265137,8.899999618530273,8.699999809265137,8.5,8.300000190734863,8.100000381469727,7.900000095367432,7.699999809265137,7.599999904632568,7.400000095367432,7.300000190734863,7.199999809265137,7.099999904632568,7.099999904632568,7.0,7.0,7.0,7.0,7.0,7.0,7.099999904632568,7.199999809265137,7.300000190734863,7.400000095367432,7.5,7.599999904632568,7.800000190734863,7.900000095367432,8.100000381469727,8.300000190734863,8.600000381469727,8.800000190734863,9.0,9.300000190734863,9.600000381469727,9.800000190734863,10.100000381469727,10.399999618530273,10.800000190734863,11.100000381469727,11.399999618530273,11.800000190734863,12.100000381469727,12.5,12.899999618530273,13.300000190734863,13.600000381469727,14.0,14.399999618530273,14.800000190734863,15.199999809265137,15.600000381469727,16.0,16.5,16.899999618530273,17.299999237060547,17.700000762939453,18.100000381469727,18.5,18.899999618530273,19.299999237060547,19.700000762939453,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,19.700000762939453,19.299999237060547, ...

# %%
MW.Variable_Search('electric')
# Out:
# CTIPe:
# E_theta140km: ['Electric field at 140 km, theta component', 'GDZ-sph', ['time', 'Elon', 'Elat'], 'V/m']
# E_lambda140km: ['Electric field at 140 km, lambda component', 'GDZ-sph', ['time', 'Elon', 'Elat'], 'V/m']
# E_theta300km: ['Electric field at 300 km, theta component', 'GDZ-sph', ['time', 'Elon', 'Elat'], 'V/m']
# E_lambda300km: ['Electric field at 300 km, lambda component', 'GDZ-sph', ['time', 'Elon', 'Elat'], 'V/m']
#
# GITM:
# V: ['electric potential', 'GDZ-sph', ['time', 'lon', 'lat', 'height'], 'V']
# j_R2: ['region 2 electric current density', 'GDZ-sph', ['time', 'lon', 'lat', 'height'], 'A/m**2']
# j_R1: ['region 1 electric current density', 'GDZ-sph', ['time', 'lon', 'lat', 'height'], 'A/m**2']
# E_perpeast: ['dynamo electric field in the perpendicular to the magnetic field direction that is "eastward"', 'GDZ-sph', ['time', 'lon', 'lat', 'height'], '']
# E_perpnorth: ['dynamo electric field in the perpendicular to the magnetic field direction that is "northward"', 'GDZ-sph', ['time', 'lon', 'lat', 'height'], '']
# E_up: ['vertical electric field velocity (up)', 'GDZ-sph', ['time', 'lon', 'lat', 'height'], 'V/m']
# E_east: ['zonal electric field (east)', 'GDZ-sph', ['time', 'lon', 'lat', 'height'], 'V/m']
# E_north: ['meridional electric field (north)', 'GDZ-sph', ['time', 'lon', 'lat', 'height'], 'V/m']
# E_mag: ['magnitude of electric field', 'GDZ-sph', ['time', 'lon', 'lat', 'height'], 'V/m']
# Q_photoe: ['heating due to the photoelectric effect', 'GDZ-sph', ['time', 'lon', 'lat', 'height'], 'K per timestep']
#
# IRI:
# No electric variables found.
#
# SWMF_IE:
# phi: ['electric potential', 'SM-sph', ['time', 'lon', 'lat'], 'kV']
# E_x: ['electric field, x component', 'SM-sph', ['time', 'lon', 'lat'], 'mV/m']
# E_y: ['electric field, y component', 'SM-sph', ['time', 'lon', 'lat'], 'mV/m']
# E_z: ['electric field, z component', 'SM-sph', ['time', 'lon', 'lat'], 'mV/m']
#
# TIEGCM:
# V_ilev: ['electric potential', 'GDZ-sph', ['time', 'lon', 'lat', 'ilev1'], 'V']
# V: ['electric potential', 'GDZ-sph', ['time', 'lon', 'lat', 'height'], 'V']
#
# OpenGGCM_GM:
# E_x: ['x component of electric field', 'GSE-car', ['time', 'x', 'x', 'x'], 'mV/m']
# E_y: ['y component of electric field', 'GSE-car', ['time', 'y', 'y', 'y'], 'mV/m']
# E_z: ['z component of electric field', 'GSE-car', ['time', 'z', 'z', 'z'], 'mV/m']
#
# AMGeO:
# E_east: ['Electric Field (eastward)', 'SM-sph', ['time', 'lon', 'lat'], 'V/m']
# E_north: ['Electric Field (equatorward)', 'SM-sph', ['time', 'lon', 'lat'], 'V/m']
# V: ['Electric Potential', 'SM-sph', ['time', 'lon', 'lat'], 'V']
#
# SuperDARN_df:
# V: ['Electric potential', 'SM-sph', ['time', 'lon', 'lat'], 'kV']
# E_sw: ['Electric field of the solar wind', 'SM-sph', ['time'], 'mV/m']
#
# SuperDARN_ea:
# V: ['Electric potential', 'SM-sph', ['time', 'lon', 'lat'], 'kV']
# E_sw: ['Electric field of the solar wind', 'SM-sph', ['time'], 'mV/m']
#
# ADELPHI:
# phi: ['Electric potential', 'MAG-sph', ['time', 'lon', 'lat'], 'kV']
# E_east: ['electric field in eastern direction (increasing longitude) ', 'MAG-sph', ['time', 'lon', 'lat'], 'mV/m']
# E_north: ['electric field in north direction (increasing latitude) ', 'MAG-sph', ['time', 'lon', 'lat'], 'mV/m']
# J_east: ['electric current in eastern direction(increasing longitude) (height integrated current density)', 'MAG-sph', ['time', 'lon', 'lat'], 'A/m']
# J_north: ['electric current in north direction (increasing latitude) (height integrated current density)', 'MAG-sph', ['time', 'lon', 'lat'], 'A/m']
#
# WACCMX:
# E_east: ['ED1: Eastward Electric Field', 'MAG-sph', ['time', 'mlon', 'mlat'], 'V/m']
# E_equator: ['ED2: Equatorward Electric Field', 'MAG-sph', ['time', 'mlon', 'mlat'], 'V/m']
# phi: ['PHIM2D: Electric Potential', 'MAG-sph', ['time', 'mlon', 'mlat'], 'V']
#
# WAMIPE:
# No electric variables found.
#
# DTM:
# No electric variables found.

# %%
MW.Variable_Search('electric', model)
# Out:
# V: ['Electric potential', 'SM-sph', ['time', 'lon', 'lat'], 'kV']
# E_sw: ['Electric field of the solar wind', 'SM-sph', ['time'], 'mV/m']

# %%
MW.Variable_Search('electric', model, file_dir)
# Out:
# V: ['Electric potential', 'SM-sph', ['time', 'lon', 'lat'], 'kV']
# E_sw: ['Electric field of the solar wind', 'SM-sph', ['time'], 'mV/m']

# %%
from kamodo_ccmc.flythrough import SatelliteFlythrough as SF
import datetime as dt
start_utcts = dt.datetime(2020, 5, 5, 12).replace(tzinfo=dt.timezone.utc).timestamp()
end_utcts = dt.datetime(2020, 5, 5, 20).replace(tzinfo=dt.timezone.utc).timestamp()-1
results = SF.ModelFlythrough(model, file_dir, ['V'], [start_utcts, end_utcts], [0., 180.], [70., -70.],
                             [400., 400.], 'GDZ-sph')
results['V']
# Out:
# Time slice index 71 added from file.
# Time slice index 72 added from file.
# Time slice index 73 added from file.
# Time slice index 119 added from file.
# Time slice index 120 added from file.
# {'V': 'kV', 'utc_time': 's', 'net_idx': '', 'c1': 'deg', 'c2': 'deg', 'c3': 'km'}
# array([-1.8302282,        nan])

# %%
results = SF.ModelFlythrough(model, file_dir, ['V'], [start_utcts], [0.], [70.],
                             [400.], 'GDZ-sph')
results['V']
# Out:
# Time slice index 71 added from file.
# Time slice index 72 added from file.
# Time slice index 73 added from file.
# {'V': 'kV', 'utc_time': 's', 'net_idx': '', 'c1': 'deg', 'c2': 'deg', 'c3': 'km'}
# array([-1.8302282])
